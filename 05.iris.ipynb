# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
iris=pd.read_csv("./05.iris.csv")

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
iris['species'].value_counts()
# Out:
# setosa        50
# virginica     50
# versicolor    50
# Name: species, dtype: int64

# %%
iris.plot(kind="scatter",x='sepal_length',y='sepal_width')

# %%
iris.sepal_length
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: float64

# %%
sns.FacetGrid(iris,hue="species",size=10).map(plt.scatter,"sepal_length","sepal_width").add_legend()
# Out:
# /home/amitrai/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(iris,hue="species",size=4)
# Out:
# /home/amitrai/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %%
import numpy as np

# %%
sns.FacetGrid(iris,hue="species",size=10).map(sns.distplot,"petal_length").add_legend()
plt.show();

# %% [markdown]
# ## PDF and CDF for pettal length

# %%
counts,bin_edges=np.histogram(iris["petal_length"],bins=10,density=True)

# %%
pdf=counts/(sum(counts))

# %%
pdf
# Out:
# array([0.24666667, 0.08666667, 0.        , 0.02      , 0.05333333,
#        0.17333333, 0.19333333, 0.12      , 0.07333333, 0.03333333])

# %%
bin_edges
# Out:
# array([1.  , 1.59, 2.18, 2.77, 3.36, 3.95, 4.54, 5.13, 5.72, 6.31, 6.9 ])

# %%
cdf=np.cumsum(pdf)

# %%
plt.plot(bin_edges[1:],pdf) #wrong 9,7 redo
plt.plot(bin_edges[1:],cdf)
plt.grid()

# %% [markdown]
# ##### their are 83% of setosa flowers that have Pettle Length <= 1.6
